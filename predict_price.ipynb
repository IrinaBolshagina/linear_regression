# %%
import pandas as pd
import matplotlib.pyplot as plt
from linear_regression import LinearRegression, load_data

# %%
model = LinearRegression()
x, y = load_data('data.csv')

# %%
print(model.train(x, y))
# Out:
# (6331.559980189939, -1105.9721327347058)

# %%
df = pd.read_csv('data.csv')
predict = 'predict'
pr = [model.predict(km) for km in x]
df[predict] = pr
df
# Out:
#         km  price  predict
# 0   240000   3650  3351.70
# 1   139800   3800  5500.80
# 2   150500   4400  5271.30
# 3   185530   4450  4519.98
# 4   176000   5250  4724.38
# 5   114800   5350  6037.00
# 6   166800   5800  4921.70
# 7    89000   5990  6590.36
# 8   144500   5999  5399.99
# 9    84000   6200  6697.60
# 10   82029   6390  6739.87
# 11   63060   6390  7146.72
# 12   74000   6600  6912.08
# 13   97500   6800  6408.05
# 14   67000   6800  7062.21
# 15   76025   6900  6868.65
# 16   48235   6900  7464.69
# 17   93000   6990  6504.57
# 18   60949   7490  7192.00
# 19   65674   7555  7090.65
# 20   54000   7990  7341.04
# 21   68500   7990  7030.04
# 22   22899   7990  8008.09
# 23   61789   8290  7173.98

# %%
plt.title('Price vs Mileage')
plt.xlabel('mileage, km')
plt.ylabel('price, euro')
plt.scatter(x, y)
plt.show()

# %%
plt.title('Price vs Mileage')
plt.xlabel('mileage, km')
plt.ylabel('price, euro')
plt.scatter(x, y)
x_points = [min(x), max(x)]
y_points = [model.predict(x) for x in x_points]
plt.plot(x_points, y_points, color='red')
plt.legend(['real data', 'predicted'])
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

data = pd.read_csv('data.csv')
x = data['km']
y = data['price']
x = np.array(x).reshape(-1, 1)
y = np.array(y)
model = LinearRegression()
model.fit(x, y)
plt.title('Price vs Mileage')
x_points = np.array([min(x), max(x)])
y_points = model.predict(x_points)
plt.plot(x_points, y_points, color='red')
plt.scatter(x, y)
plt.show()

# %%
df = pd.read_csv('data.csv')
predict = 'predict'
df[predict] = model.predict(x)
presision = model.score(x, y)
print(presision)
df
# Out:
# 0.7329747078314965
#         km  price      predict
# 0   240000   3650  3351.848388
# 1   139800   3800  5501.034540
# 2   150500   4400  5271.530629
# 3   185530   4450  4520.173435
# 4   176000   5250  4724.582058
# 5   114800   5350  6037.258630
# 6   166800   5800  4921.912523
# 7    89000   5990  6590.641890
# 8   144500   5999  5400.224411
# 9    84000   6200  6697.886708
# 10   82029   6390  6740.162615
# 11   63060   6390  7147.028006
# 12   74000   6600  6912.376344
# 13   97500   6800  6408.325700
# 14   67000   6800  7062.519089
# 15   76025   6900  6868.942193
# 16   48235   6900  7465.008891
# 17   93000   6990  6504.846036
# 18   60949   7490  7192.306768
# 19   65674   7555  7090.960415
# 20   54000   7990  7341.355616
# 21   68500   7990  7030.345644
# 22   22899   7990  8008.439833
# 23   61789   8290  7174.289639
